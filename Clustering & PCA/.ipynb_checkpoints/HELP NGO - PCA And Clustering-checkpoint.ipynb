# %% [markdown]
# # <center>HELP International NGO</center>

# %% [markdown]
# ## Problem Statement
# HELP International is an international humanitarian NGO that is committed to fighting poverty and providing the people of backward countries with basic amenities and relief during the time of disasters and natural calamities. <br>
# Key problem statements are:
# **<ul>
#     <li>How to use newly received $10 million funding strategically and effectively</li>
#     <li>Categorise the countries using socio-economic and health factors.</li>
#     <li>Choose appropriate countries that are in the direst need of aid.</li>
# </ul>**

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load Data and Perform EDA

# %%
data_dict = pd.read_csv('data-dictionary.csv', index_col='Column Name')
pd.set_option('display.max_colwidth', -1)
data_dict
# Out:
#                                                                                                                   Description
# Column Name
# country      Name of the country
# child_mort   Death of children under 5 years of age per 1000 live births
# exports      Exports of goods and services. Given as %age of the Total GDP
# health       Total health spending as %age of Total GDP
# imports      Imports of goods and services. Given as %age of the Total GDP
# Income       Net income per person
# Inflation    The measurement of the annual growth rate of the Total GDP
# life_expec   The average number of years a new born child would live if the current mortality patterns are to remain the same
# total_fer    The number of children that would be born to each woman if the current age-fertility rates remain the same.
# gdpp         The GDP per capita. Calculated as the Total GDP divided by the total population.

# %%
countryDf = pd.read_csv('Country-data.csv')
countryDf.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0  Afghanistan          90.2        10.0     7.58    44.9     1610
# 1  Albania              16.6        28.0     6.55    48.6     9930
# 2  Algeria              27.3        38.4     4.17    31.4     12900
# 3  Angola               119.0       62.3     2.85    42.9     5900
# 4  Antigua and Barbuda  10.3        45.5     6.03    58.9     19100
#
#    inflation  life_expec  total_fer   gdpp
# 0  9.44       56.2        5.82       553
# 1  4.49       76.3        1.65       4090
# 2  16.10      76.5        2.89       4460
# 3  22.40      60.1        6.16       3530
# 4  1.44       76.8        2.13       12200

# %%
countryDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
# country       167 non-null object
# child_mort    167 non-null float64
# exports       167 non-null float64
# health        167 non-null float64
# imports       167 non-null float64
# income        167 non-null int64
# inflation     167 non-null float64
# life_expec    167 non-null float64
# total_fer     167 non-null float64
# gdpp          167 non-null int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.1+ KB

# %%
countryDf.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# **No Missing Data**

# %%
countryDf.shape
# Out:
# (167, 10)

# %%
countryDf[countryDf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, child_mort, exports, health, imports, income, inflation, life_expec, total_fer, gdpp]
# Index: []

# %%
sns.pairplot(countryDf)

# %%
countryDf.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000
# mean   38.270060   41.108976   6.815689    46.890215   17144.688623
# std    40.328931   27.412010   2.746837    24.209589   19278.067698
# min    2.600000    0.109000    1.810000    0.065900    609.000000
# 25%    8.250000    23.800000   4.920000    30.200000   3355.000000
# 50%    19.300000   35.000000   6.320000    43.300000   9960.000000
# 75%    62.100000   51.350000   8.600000    58.750000   22800.000000
# max    208.000000  200.000000  17.900000   174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000  167.000000
# mean   7.781832    70.555689   2.947964    12964.155689
# std    10.570704   8.893172    1.513848    18328.704809
# min   -4.210000    32.100000   1.150000    231.000000
# 25%    1.810000    65.300000   1.795000    1330.000000
# 50%    5.390000    73.100000   2.410000    4660.000000
# 75%    10.750000   76.800000   3.880000    14050.000000
# max    104.000000  82.800000   7.490000    105000.000000

# %%
countryDf[['country']].describe()
# Out:
#        country
# count   167
# unique  167
# top     Latvia
# freq    1

# %% [markdown]
# **Here we have 167 rows containing 167 unique countries. <br>
# So, no duplicate data rows**

# %% [markdown]
# **Outlier Analysis**

# %%
plt.figure(figsize=(18,10))
numericCol = countryDf.columns.drop('country')
index = 1
for col in numericCol:
    plt.subplot(3,3,index)
    sns.boxplot(data=countryDf, y=col)
    index = index + 1

# %%
plt.figure(figsize=(18,10))
numericCol = countryDf.columns.drop('country')
index = 1
for col in numericCol:
    plt.subplot(3,3,index)
    sns.distplot(countryDf[col])
    index = index + 1

# %% [markdown]
# **Analysing Outlier based on different features**

# %%
countryDf[countryDf['child_mort'] > 100]
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 3    Angola                    119.0       62.3     2.85    42.9     5900
# 17   Benin                     111.0       23.8     4.10    37.2     1820
# 25   Burkina Faso              116.0       19.2     6.74    29.6     1430
# 28   Cameroon                  108.0       22.2     5.13    27.0     2660
# 31   Central African Republic  149.0       11.8     3.98    26.5     888
# 32   Chad                      150.0       36.8     4.53    43.5     1930
# 37   Congo, Dem. Rep.          116.0       41.1     7.91    49.6     609
# 40   Cote d'Ivoire             111.0       50.6     5.30    43.3     2690
# 49   Equatorial Guinea         111.0       85.8     4.48    58.9     33700
# 63   Guinea                    109.0       30.3     4.93    43.2     1190
# 64   Guinea-Bissau             114.0       14.9     8.50    35.2     1390
# 66   Haiti                     208.0       15.3     6.91    64.7     1500
# 97   Mali                      137.0       22.8     4.98    35.1     1870
# 106  Mozambique                101.0       31.5     5.21    46.2     918
# 112  Niger                     123.0       22.2     5.16    49.1     814
# 113  Nigeria                   130.0       25.3     5.07    17.4     5150
# 132  Sierra Leone              160.0       16.8     13.10   34.5     1220
#
#      inflation  life_expec  total_fer   gdpp
# 3    22.400     60.1        6.16       3530
# 17   0.885      61.8        5.36       758
# 25   6.810      57.9        5.87       575
# 28   1.910      57.3        5.11       1310
# 31   2.010      47.5        5.21       446
# 32   6.390      56.5        6.59       897
# 37   20.800     57.5        6.54       334
# 40   5.390      56.3        5.27       1220
# 49   24.900     60.9        5.21       17100
# 63   16.100     58.0        5.34       648
# 64   2.970      55.6        5.05       547
# 66   5.450      32.1        3.33       662
# 97   4.370      59.5        6.55       708
# 106  7.640      54.5        5.56       419
# 112  2.550      58.8        7.49       348
# 113  104.000    60.5        5.84       2330
# 132  17.200     55.0        5.20       399

# %%
countryDf[countryDf['life_expec'] < 50]
# Out:
#                      country  child_mort  exports  health  imports  income  \
# 31  Central African Republic  149.0       11.8     3.98    26.5     888
# 66  Haiti                     208.0       15.3     6.91    64.7     1500
# 87  Lesotho                   99.7        39.4     11.10   101.0    2380
#
#     inflation  life_expec  total_fer  gdpp
# 31  2.01       47.5        5.21       446
# 66  5.45       32.1        3.33       662
# 87  4.15       46.5        3.30       1170

# %% [markdown]
# **High Child_mort** rate &  **low life_expec** rate is big concern.<BR>
# If we check other features it shows under developed countries (Where GDP capita is low as well and heath expenditure as compare to GDP is low also low income per person) facing such kind of problem.

# %%
countryDf[countryDf['exports'] > 100]
# Out:
#         country  child_mort  exports  health  imports  income  inflation  \
# 73   Ireland     4.2         103.0    9.19    86.5     45700  -3.220
# 91   Luxembourg  2.8         175.0    7.77    142.0    91700   3.620
# 98   Malta       6.8         153.0    8.65    154.0    28300   3.830
# 133  Singapore   2.8         200.0    3.96    174.0    72100  -0.046
#
#      life_expec  total_fer    gdpp
# 73   80.4        2.05       48700
# 91   81.3        1.63       105000
# 98   80.3        1.36       21100
# 133  82.7        1.15       46600

# %%
countryDf[countryDf['income'] > 50000]
# Out:
#                   country  child_mort  exports  health  imports  income  \
# 23   Brunei                10.5        67.4     2.84    28.0     80600
# 82   Kuwait                10.8        66.7     2.63    30.4     75200
# 91   Luxembourg            2.8         175.0    7.77    142.0    91700
# 114  Norway                3.2         39.7     9.48    28.5     62300
# 123  Qatar                 9.0         62.3     1.81    23.8     125000
# 133  Singapore             2.8         200.0    3.96    174.0    72100
# 145  Switzerland           4.5         64.0     11.50   53.3     55500
# 157  United Arab Emirates  8.6         77.7     3.66    63.6     57600
#
#      inflation  life_expec  total_fer    gdpp
# 23   16.700     77.1        1.84       35300
# 82   11.200     78.2        2.21       38500
# 91   3.620      81.3        1.63       105000
# 114  5.950      81.0        1.95       87800
# 123  6.980      79.5        2.07       70300
# 133 -0.046      82.7        1.15       46600
# 145  0.317      82.2        1.52       74600
# 157  12.500     76.5        1.87       35000

# %%
countryDf[countryDf['gdpp'] > 40000]
# Out:
#            country  child_mort  exports  health  imports  income  inflation  \
# 7    Australia      4.8         19.8     8.73    20.9     41400   1.160
# 8    Austria        4.3         51.3     11.00   47.8     43200   0.873
# 15   Belgium        4.5         76.4     10.70   74.7     41100   1.880
# 29   Canada         5.6         29.1     11.30   31.0     40700   2.870
# 44   Denmark        4.1         50.5     11.40   43.6     44000   3.220
# 53   Finland        3.0         38.7     8.95    37.4     39800   0.351
# 54   France         4.2         26.8     11.90   28.1     36900   1.050
# 58   Germany        4.2         42.3     11.60   37.1     40400   0.758
# 68   Iceland        2.6         53.4     9.40    43.3     38800   5.470
# 73   Ireland        4.2         103.0    9.19    86.5     45700  -3.220
# 77   Japan          3.2         15.0     9.49    13.6     35800  -1.900
# 91   Luxembourg     2.8         175.0    7.77    142.0    91700   3.620
# 110  Netherlands    4.5         72.0     11.90   63.6     45500   0.848
# 114  Norway         3.2         39.7     9.48    28.5     62300   5.950
# 123  Qatar          9.0         62.3     1.81    23.8     125000  6.980
# 133  Singapore      2.8         200.0    3.96    174.0    72100  -0.046
# 144  Sweden         3.0         46.2     9.63    40.7     42900   0.991
# 145  Switzerland    4.5         64.0     11.50   53.3     55500   0.317
# 159  United States  7.3         12.4     17.90   15.8     49400   1.220
#
#      life_expec  total_fer    gdpp
# 7    82.0        1.93       51900
# 8    80.5        1.44       46900
# 15   80.0        1.86       44400
# 29   81.3        1.63       47400
# 44   79.5        1.87       58000
# 53   80.0        1.87       46200
# 54   81.4        2.03       40600
# 58   80.1        1.39       41800
# 68   82.0        2.20       41900
# 73   80.4        2.05       48700
# 77   82.8        1.39       44500
# 91   81.3        1.63       105000
# 110  80.7        1.79       50300
# 114  81.0        1.95       87800
# 123  79.5        2.07       70300
# 133  82.7        1.15       46600
# 144  81.5        1.98       52100
# 145  82.2        1.52       74600
# 159  78.7        1.93       48400

# %%
countryDf[countryDf['inflation'] > 20]
# Out:
#                country  child_mort  exports  health  imports  income  \
# 3    Angola             119.0       62.3     2.85    42.9     5900
# 5    Argentina          14.5        18.9     8.10    16.0     18700
# 37   Congo, Dem. Rep.   116.0       41.1     7.91    49.6     609
# 38   Congo, Rep.        63.9        85.1     2.46    54.7     5190
# 49   Equatorial Guinea  111.0       85.8     4.48    58.9     33700
# 103  Mongolia           26.1        46.7     5.44    56.7     7710
# 113  Nigeria            130.0       25.3     5.07    17.4     5150
# 140  Sri Lanka          11.2        19.6     2.94    26.8     8560
# 149  Timor-Leste        62.6        2.2      9.12    27.8     1850
# 163  Venezuela          17.1        28.5     4.91    17.6     16500
# 165  Yemen              56.3        30.0     5.18    34.4     4480
#
#      inflation  life_expec  total_fer   gdpp
# 3    22.4       60.1        6.16       3530
# 5    20.9       75.8        2.37       10300
# 37   20.8       57.5        6.54       334
# 38   20.7       60.4        4.95       2740
# 49   24.9       60.9        5.21       17100
# 103  39.2       66.2        2.64       2650
# 113  104.0      60.5        5.84       2330
# 140  22.8       74.4        2.20       2810
# 149  26.5       71.1        6.23       3600
# 163  45.9       75.4        2.47       13500
# 165  23.6       67.5        4.67       1310

# %% [markdown]
# There are few outliners in Data, but data set is very small with 167 Observation.<BR>
# So will keep all data as is and perform further analysis.

# %%
countryDf.corr()
# Out:
#             child_mort   exports    health   imports    income  inflation  \
# child_mort  1.000000   -0.318093 -0.200402 -0.127211 -0.524315  0.288276
# exports    -0.318093    1.000000 -0.114408  0.737381  0.516784 -0.107294
# health     -0.200402   -0.114408  1.000000  0.095717  0.129579 -0.255376
# imports    -0.127211    0.737381  0.095717  1.000000  0.122406 -0.246994
# income     -0.524315    0.516784  0.129579  0.122406  1.000000 -0.147756
# inflation   0.288276   -0.107294 -0.255376 -0.246994 -0.147756  1.000000
# life_expec -0.886676    0.316313  0.210692  0.054391  0.611962 -0.239705
# total_fer   0.848478   -0.320011 -0.196674 -0.159048 -0.501840  0.316921
# gdpp       -0.483032    0.418725  0.345966  0.115498  0.895571 -0.221631
#
#             life_expec  total_fer      gdpp
# child_mort -0.886676    0.848478  -0.483032
# exports     0.316313   -0.320011   0.418725
# health      0.210692   -0.196674   0.345966
# imports     0.054391   -0.159048   0.115498
# income      0.611962   -0.501840   0.895571
# inflation  -0.239705    0.316921  -0.221631
# life_expec  1.000000   -0.760875   0.600089
# total_fer  -0.760875    1.000000  -0.454910
# gdpp        0.600089   -0.454910   1.000000

# %%
#Check correlation with heatmap
corr = countryDf.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(10,5))
sns.heatmap(corr, cmap='RdBu', annot=True,  mask=mask, center=0, linewidths= 0.1)
plt.show()

# %% [markdown]
# There are few features are highly  corelated.
# Will can drop few of the feature like **Total_Fer, Income, Exports** <BR>
# But will keep all the features as is and use **PCA** to Solve **Multicollinearity** factor.

# %%
countryDf.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000  167.000000
# mean   38.270060   41.108976   6.815689    46.890215   17144.688623
# std    40.328931   27.412010   2.746837    24.209589   19278.067698
# min    2.600000    0.109000    1.810000    0.065900    609.000000
# 25%    8.250000    23.800000   4.920000    30.200000   3355.000000
# 50%    19.300000   35.000000   6.320000    43.300000   9960.000000
# 75%    62.100000   51.350000   8.600000    58.750000   22800.000000
# max    208.000000  200.000000  17.900000   174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000  167.000000
# mean   7.781832    70.555689   2.947964    12964.155689
# std    10.570704   8.893172    1.513848    18328.704809
# min   -4.210000    32.100000   1.150000    231.000000
# 25%    1.810000    65.300000   1.795000    1330.000000
# 50%    5.390000    73.100000   2.410000    4660.000000
# 75%    10.750000   76.800000   3.880000    14050.000000
# max    104.000000  82.800000   7.490000    105000.000000

# %% [markdown]
# Few of the features are corelated with each other, instead of checking & removing features manually will implement PCA.

# %% [markdown]
# ### PCA Implementation
# Before performing PCA will first scale data on Standard Scalar as income & gdpp feature have wide spread as compare to other features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
trainDf = countryDf.drop(labels='country', axis=1)
sc = StandardScaler()
scalledData = sc.fit_transform(trainDf)
trainDf_scalled = pd.DataFrame(data=scalledData, columns=trainDf.columns)

# %%
pca = PCA(svd_solver='randomized', random_state=100)

# %%
pca.fit(trainDf_scalled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=100,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-0.41951945,  0.28389698,  0.15083782,  0.16148244,  0.39844111,
#         -0.19317293,  0.42583938, -0.40372896,  0.39264482],
#        [ 0.19288394,  0.61316349, -0.24308678,  0.67182064,  0.02253553,
#         -0.00840447, -0.22270674,  0.15523311, -0.0460224 ],
#        [-0.02954353,  0.14476069, -0.59663237, -0.29992674,  0.3015475 ,
#          0.64251951,  0.11391854,  0.01954925,  0.12297749],
#        [ 0.37065326,  0.00309102,  0.4618975 , -0.07190746,  0.39215904,
#          0.15044176, -0.20379723,  0.37830365,  0.53199457],
#        [-0.16896968,  0.05761584,  0.51800037,  0.25537642, -0.2471496 ,
#          0.7148691 ,  0.1082198 , -0.13526221, -0.18016662],
#        [ 0.20062815, -0.05933283,  0.00727646, -0.03003154,  0.16034699,
#          0.06628537, -0.60112652, -0.75068875,  0.01677876],
#        [-0.07948854, -0.70730269, -0.24983051,  0.59218953,  0.09556237,
#          0.10463252,  0.01848639,  0.02882643,  0.24299776],
#        [-0.68274306, -0.01419742,  0.07249683, -0.02894642,  0.35262369,
#         -0.01153775, -0.50466425,  0.29335267, -0.24969636],
#        [ 0.3275418 , -0.12308207,  0.11308797,  0.09903717,  0.61298247,
#         -0.02523614,  0.29403981, -0.02633585, -0.62564572]])

# %%
features = pd.Series(trainDf_scalled.columns, name='Feature')
pcaDF = pd.DataFrame(data=pca.components_.T, columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9'])
pcaDF = pd.concat([features, pcaDF], axis=1)
pcaDF
# Out:
#       Feature       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0  child_mort -0.419519  0.192884 -0.029544  0.370653 -0.168970  0.200628
# 1  exports     0.283897  0.613163  0.144761  0.003091  0.057616 -0.059333
# 2  health      0.150838 -0.243087 -0.596632  0.461897  0.518000  0.007276
# 3  imports     0.161482  0.671821 -0.299927 -0.071907  0.255376 -0.030032
# 4  income      0.398441  0.022536  0.301548  0.392159 -0.247150  0.160347
# 5  inflation  -0.193173 -0.008404  0.642520  0.150442  0.714869  0.066285
# 6  life_expec  0.425839 -0.222707  0.113919 -0.203797  0.108220 -0.601127
# 7  total_fer  -0.403729  0.155233  0.019549  0.378304 -0.135262 -0.750689
# 8  gdpp        0.392645 -0.046022  0.122977  0.531995 -0.180167  0.016779
#
#         PC7       PC8       PC9
# 0 -0.079489 -0.682743  0.327542
# 1 -0.707303 -0.014197 -0.123082
# 2 -0.249831  0.072497  0.113088
# 3  0.592190 -0.028946  0.099037
# 4  0.095562  0.352624  0.612982
# 5  0.104633 -0.011538 -0.025236
# 6  0.018486 -0.504664  0.294040
# 7  0.028826  0.293353 -0.026336
# 8  0.242998 -0.249696 -0.625646

# %%
#Cumulative variance explained by PCA component
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.4595174 , 0.63133365, 0.76137624, 0.87190786, 0.94530998,
#        0.97015232, 0.98275663, 0.99256944, 1.        ])

# %%
#Plot scree plot to check Cumulative Variance Explaining by PCA component
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %% [markdown]
# As per above scree plot **5** PCA component explains **94.5%** of variance, if we take **6** components will get hardly **1.5%** of gain in variance explained by component.<BR>
# So will take **5** component and build clustering model.

# %%
from sklearn.decomposition import IncrementalPCA
final_pca = IncrementalPCA(n_components=5)
trainDf_pca = final_pca.fit_transform(trainDf_scalled)

# %%
final_pca.components_
# Out:
# array([[-0.41967749,  0.28371974,  0.15090765,  0.16157087,  0.39861811,
#         -0.1928264 ,  0.42549267, -0.40396116,  0.39266855],
#        [ 0.19312245,  0.61357956, -0.24350339,  0.67130924,  0.02407378,
#         -0.00332551, -0.22455856,  0.15219983, -0.04573737],
#        [-0.03436069,  0.14687014, -0.6044529 , -0.30913862,  0.30002773,
#          0.62984364,  0.12047131,  0.02795883,  0.11959861],
#        [ 0.37107257,  0.00490633,  0.45432934, -0.07721714,  0.39426589,
#          0.14920805, -0.19996777,  0.38322405,  0.53417883],
#        [-0.18390053,  0.07043899,  0.51574709,  0.24222051, -0.25069755,
#          0.71769058,  0.13980886, -0.08575814, -0.17810981]])

# %%
trainDf_pca.shape
# Out:
# (167, 5)

# %%
#Check correlation with heatmap
corr = np.corrcoef(trainDf_pca.transpose()).round(2)

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

#plt.figure(figsize=(5,5))
sns.heatmap(corr, cmap='RdBu', annot=True,  mask=mask, center=0, linewidths= 0.1)
plt.show()

# %% [markdown]
# There is no Correlation between any 2 features.

# %%
features = pd.Series(trainDf_scalled.columns, name='Feature')
final_pcaDF = pd.DataFrame(data=final_pca.components_.T, columns=['PC1','PC2','PC3','PC4','PC5'])
final_pcaDF = pd.concat([features, final_pcaDF], axis=1)
final_pcaDF
# Out:
#       Feature       PC1       PC2       PC3       PC4       PC5
# 0  child_mort -0.419677  0.193122 -0.034361  0.371073 -0.183901
# 1  exports     0.283720  0.613580  0.146870  0.004906  0.070439
# 2  health      0.150908 -0.243503 -0.604453  0.454329  0.515747
# 3  imports     0.161571  0.671309 -0.309139 -0.077217  0.242221
# 4  income      0.398618  0.024074  0.300028  0.394266 -0.250698
# 5  inflation  -0.192826 -0.003326  0.629844  0.149208  0.717691
# 6  life_expec  0.425493 -0.224559  0.120471 -0.199968  0.139809
# 7  total_fer  -0.403961  0.152200  0.027959  0.383224 -0.085758
# 8  gdpp        0.392669 -0.045737  0.119599  0.534179 -0.178110

# %%
trainDf_pca = pd.DataFrame(data=trainDf_pca)
trainDf_pca.columns = ['PC1','PC2','PC3','PC4','PC5']
trainDf_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5
# 0 -2.913000  0.091969 -0.721242  1.001838 -0.146765
# 1  0.429870 -0.589373 -0.328611 -1.165014  0.153205
# 2 -0.285289 -0.452139  1.232051 -0.857767  0.191227
# 3 -2.932714  1.698771  1.525076  0.855595 -0.214778
# 4  1.033371  0.133853 -0.216699 -0.846638 -0.193186

# %% [markdown]
# ### Model Building : Using Clustering Algorithms

# %% [markdown]
# First analyze  **Hopkins Statistic** to check data tendency/pattern fits for clustering or not.

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from math import isnan
 
def HopkinsStats(data):
    d = data.shape[1]
    n = len(data) # rows
    m = int(0.1 * n)
    
    nbrs = NearestNeighbors(n_neighbors=1).fit(data.values)
    
    rand_data = sample(range(0, n, 1), m)
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(np.random.uniform(np.amin(data,axis=0),np.amax(data,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(data.iloc[rand_data[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])

    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        H = 0

    return H

# %%
HopkinsStats(trainDf_pca)
# Out:
# 0.7432494526600084

# %% [markdown]
# If Hopkins Statistics have value between **0.7 - 0.99** than data is good for clustering. <BR>
# Our Hopkins Stats value is ** > 0.7** which show good tendency of clustering. <BR><BR>
# Will implement **K-Mean & Hierarchical Clustering** algorithm on data set.

# %% [markdown]
# ### K-Mean Clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# For K-Mean algorithm we have to first find of number on Cluster required of analysis.

# %% [markdown]
# **Sum of Squared Error** method to find number of clusters.

# %%
sse = []
for k in range(2,15):
    kMean_model = KMeans(n_clusters=k, random_state= 0, max_iter=50)
    kMean_model.fit(trainDf_pca)
    sse.append([k,kMean_model.inertia_])

# %%
plt.plot(pd.DataFrame(sse)[0], pd.DataFrame(sse)[1]);
plt.ylabel("Sum Of Squared Error")
plt.xlabel("No Of Cluster")
plt.show()

# %% [markdown]
# **Elbow Method** to derive number of clusters.<BR>
# Will use **Silhouette Analysis**.

# %%
from sklearn.metrics import silhouette_score
ss = []
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(trainDf_pca)
    ss.append([k, silhouette_score(trainDf_pca, kmeans.labels_)])

plt.plot(pd.DataFrame(ss)[0], pd.DataFrame(ss)[1], '-gD')
plt.show()

# %% [markdown]
# **Sum of Squared Error** method shows more cluster are better, three is significant drop in SSE till approx. 8 cluster. But having 8 clusters are not good approach. <BR><BR>
# **Elbow Method: Using Silhouette Analysis** technique shows 5 clusters are good for modelling.

# %%
kMeans_Clust5 = KMeans(n_clusters=5, max_iter=50, random_state=0)
kMeans_Clust5.fit(trainDf_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
print(kMeans_Clust5.labels_.shape)
kMeans_Clust5.labels_
# Out:
# (167,)
# array([0, 3, 3, 0, 3, 3, 3, 1, 1, 3, 3, 3, 3, 3, 3, 1, 3, 0, 3, 3, 3, 0,
#        3, 1, 3, 0, 0, 3, 0, 1, 3, 0, 0, 3, 3, 3, 0, 0, 0, 3, 0, 3, 1, 3,
#        1, 3, 3, 3, 3, 0, 0, 3, 3, 1, 1, 0, 0, 3, 1, 0, 1, 3, 3, 0, 0, 3,
#        0, 3, 1, 3, 3, 3, 0, 1, 1, 1, 3, 1, 3, 3, 0, 0, 1, 3, 0, 3, 3, 0,
#        0, 3, 3, 2, 3, 0, 0, 3, 3, 0, 2, 0, 3, 3, 3, 4, 3, 3, 0, 3, 0, 3,
#        1, 1, 0, 4, 1, 3, 0, 3, 3, 3, 3, 3, 1, 1, 3, 3, 0, 3, 3, 0, 3, 3,
#        0, 2, 3, 1, 3, 0, 1, 1, 3, 3, 0, 3, 1, 1, 3, 0, 3, 0, 0, 3, 3, 3,
#        3, 0, 3, 1, 1, 1, 3, 3, 3, 4, 3, 0, 0])

# %%
kMean_DF = pd.concat([pd.Series(kMeans_Clust5.labels_, name="ClusterId"), countryDf, trainDf_pca], axis=1)
kMean_DF.head()
# Out:
#    ClusterId              country  child_mort  exports  health  imports  \
# 0  0          Afghanistan          90.2        10.0     7.58    44.9
# 1  3          Albania              16.6        28.0     6.55    48.6
# 2  3          Algeria              27.3        38.4     4.17    31.4
# 3  0          Angola               119.0       62.3     2.85    42.9
# 4  3          Antigua and Barbuda  10.3        45.5     6.03    58.9
#
#    income  inflation  life_expec  total_fer   gdpp       PC1       PC2  \
# 0  1610    9.44       56.2        5.82       553   -2.913000  0.091969
# 1  9930    4.49       76.3        1.65       4090   0.429870 -0.589373
# 2  12900   16.10      76.5        2.89       4460  -0.285289 -0.452139
# 3  5900    22.40      60.1        6.16       3530  -2.932714  1.698771
# 4  19100   1.44       76.8        2.13       12200  1.033371  0.133853
#
#         PC3       PC4       PC5
# 0 -0.721242  1.001838 -0.146765
# 1 -0.328611 -1.165014  0.153205
# 2  1.232051 -0.857767  0.191227
# 3  1.525076  0.855595 -0.214778
# 4 -0.216699 -0.846638 -0.193186

# %%
kMean_DF['ClusterId'].value_counts()
# Out:
# 3    85
# 0    46
# 1    30
# 4    3
# 2    3
# Name: ClusterId, dtype: int64

# %%
grpMean = kMean_DF.groupby(by=['ClusterId']).mean()
grpMean = grpMean.reset_index()
grpMean
# Out:
#    ClusterId  child_mort     exports    health     imports        income  \
# 0  0          92.156522   29.235000   6.417174  42.865217   3916.152174
# 1  1          4.953333    45.826667   9.168667  39.736667   45250.000000
# 2  2          4.133333    176.000000  6.793333  156.666667  64033.333333
# 3  3          21.384706   41.377518   6.260824  48.294893   12988.941176
# 4  4          57.733333   33.500000   5.140000  30.566667   9786.666667
#
#    inflation  life_expec  total_fer          gdpp       PC1       PC2  \
# 0  10.020109  59.158696   4.990000   1913.521739  -2.380853  0.420680
# 1  2.742200   80.376667   1.795333   43333.333333  2.585965 -0.866463
# 2  2.468000   81.433333   1.380000   57566.666667  5.460016  5.434769
# 3  6.586718   72.985882   2.280235   6891.905882   0.258393 -0.105182
# 4  63.033333  67.366667   3.650000   6160.000000  -2.134399 -0.240408
#
#         PC3       PC4       PC5
# 0 -0.232433  0.654765 -0.255569
# 1  0.074494  0.985386 -0.249552
# 2  0.178056  0.901254  0.453649
# 3 -0.035036 -0.756350  0.095787
# 4  3.633679  0.635058  3.246646

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(data=kMean_DF, x='PC1', y='PC2', hue='ClusterId', style='ClusterId', legend="full")

# %% [markdown]
# All clusters have clear segregation except Cluster 4. <BR>
# PC1 & PC2 data points segregate data properly, will choose some feature variable to analyze clusters.<BR>
# Will choose features based on Linear Combination value of features in PC1 & PC2

# %%
final_pcaDF
# Out:
#       Feature       PC1       PC2       PC3       PC4       PC5
# 0  child_mort -0.419677  0.193122 -0.034361  0.371073 -0.183901
# 1  exports     0.283720  0.613580  0.146870  0.004906  0.070439
# 2  health      0.150908 -0.243503 -0.604453  0.454329  0.515747
# 3  imports     0.161571  0.671309 -0.309139 -0.077217  0.242221
# 4  income      0.398618  0.024074  0.300028  0.394266 -0.250698
# 5  inflation  -0.192826 -0.003326  0.629844  0.149208  0.717691
# 6  life_expec  0.425493 -0.224559  0.120471 -0.199968  0.139809
# 7  total_fer  -0.403961  0.152200  0.027959  0.383224 -0.085758
# 8  gdpp        0.392669 -0.045737  0.119599  0.534179 -0.178110

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.scatterplot(data=kMean_DF, x='gdpp', y='exports', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,2)
sns.scatterplot(data=kMean_DF, x='gdpp', y='life_expec', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,3)
sns.scatterplot(data=kMean_DF, x='gdpp', y='child_mort', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,4)
sns.scatterplot(data=kMean_DF, x='gdpp', y='income', hue='ClusterId', style='ClusterId', legend="full")

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
sns.barplot(data=grpMean, x='ClusterId', y='child_mort')
plt.subplot(3,3,2)
sns.barplot(data=grpMean, x='ClusterId', y='exports')
plt.subplot(3,3,3)
sns.barplot(data=grpMean, x='ClusterId', y='health')
plt.subplot(3,3,4)
sns.barplot(data=grpMean, x='ClusterId', y='imports')
plt.subplot(3,3,5)
sns.barplot(data=grpMean, x='ClusterId', y='income')
plt.subplot(3,3,6)
sns.barplot(data=grpMean, x='ClusterId', y='inflation')
plt.subplot(3,3,7)
sns.barplot(data=grpMean, x='ClusterId', y='life_expec')
plt.subplot(3,3,8)
sns.barplot(data=grpMean, x='ClusterId', y='total_fer')
plt.subplot(3,3,9)
sns.barplot(data=grpMean, x='ClusterId', y='gdpp')
plt.show()

# %% [markdown]
# Key features of Developed Countries are: High Income, High GDPP, Low Inflation, High Life Expectancy, High Health Spending, Low Child Mortality Rate, etc.  <BR>
# In contrast Under Developed Countries are having: Low Income, Low GDPP, High Inflation, High Child Mortality rate, Low Life Expectancy

# %% [markdown]
# Based on above graph we can say that Countries in **Cluster Id - 0** are under developed countries. <BR>
# Countries in **Cluster Id -  4 ** doing better than **Cluster Id - 0**<BR>
# Looks like Countries in **Cluster Id - 1 & 2 ** and developed countries.<BR><BR>
#
# Will verify each cluster and for our analysis will stick to **Cluster 0 & 4**

# %%
kMean_DF[(kMean_DF['ClusterId'] == 0)].describe()
# Out:
#        ClusterId  child_mort  exports     health     imports        income  \
# count  46.0       46.000000   46.0000  46.000000  46.000000   46.000000
# mean   0.0        92.156522   29.2350  6.417174   42.865217   3916.152174
# std    0.0        33.279294   18.3521  2.684088   17.530940   5701.229380
# min    0.0        36.900000   2.2000   2.200000   17.200000   609.000000
# 25%    0.0        63.750000   16.8750  4.515000   30.225000   1390.000000
# 50%    0.0        89.750000   23.8000  5.675000   41.500000   1860.000000
# 75%    0.0        111.000000  38.8000  8.202500   49.525000   3357.500000
# max    0.0        208.000000  85.8000  13.100000  101.000000  33700.000000
#
#        inflation  life_expec  total_fer          gdpp        PC1        PC2  \
# count  46.000000  46.000000   46.000000  46.000000     46.000000  46.000000
# mean   10.020109  59.158696   4.990000   1913.521739  -2.380853   0.420680
# std    7.335460   6.511719    1.045401   2988.137865   0.811423   0.819955
# min    0.885000   32.100000   2.590000   231.000000   -4.408941  -1.176966
# 25%    3.940000   56.575000   4.522500   548.500000   -2.918784  -0.158308
# 50%    8.855000   59.400000   5.055000   833.000000   -2.366226   0.352118
# 75%    16.475000  62.875000   5.527500   1422.500000  -1.820599   0.957801
# max    26.500000  71.100000   7.490000   17100.000000 -0.881576   2.372017
#
#              PC3        PC4        PC5
# count  46.000000  46.000000  46.000000
# mean  -0.232433   0.654765  -0.255569
# std    1.004885   0.659017   0.749896
# min   -2.545362  -0.475888  -1.871714
# 25%   -0.715760   0.201939  -0.789771
# 50%   -0.234935   0.602034  -0.260961
# 75%    0.350896   1.085210   0.232688
# max    1.758962   2.563263   1.418366

# %%
#Under Developed Countries
kMean_DF[(kMean_DF['ClusterId'] == 0)].sort_values(by=['child_mort'], ascending=False).head(10)
# Out:
#      ClusterId                   country  child_mort  exports  health  \
# 66   0          Haiti                     208.0       15.3     6.91
# 132  0          Sierra Leone              160.0       16.8     13.10
# 32   0          Chad                      150.0       36.8     4.53
# 31   0          Central African Republic  149.0       11.8     3.98
# 97   0          Mali                      137.0       22.8     4.98
# 112  0          Niger                     123.0       22.2     5.16
# 3    0          Angola                    119.0       62.3     2.85
# 25   0          Burkina Faso              116.0       19.2     6.74
# 37   0          Congo, Dem. Rep.          116.0       41.1     7.91
# 64   0          Guinea-Bissau             114.0       14.9     8.50
#
#      imports  income  inflation  life_expec  total_fer  gdpp       PC1  \
# 66   64.7     1500    5.45       32.1        3.33       662  -4.408941
# 132  34.5     1220    17.20      55.0        5.20       399  -3.381422
# 32   43.5     1930    6.39       56.5        6.59       897  -3.558249
# 31   26.5     888     2.01       47.5        5.21       446  -3.965158
# 97   35.1     1870    4.37       59.5        6.55       708  -3.413005
# 112  49.1     814     2.55       58.8        7.49       348  -3.450990
# 3    42.9     5900    22.40      60.1        6.16       3530 -2.932714
# 25   29.6     1430    6.81       57.9        5.87       575  -3.122430
# 37   49.6     609     20.80      57.5        6.54       334  -3.173421
# 64   35.2     1390    2.97       55.6        5.05       547  -2.833802
#
#           PC2       PC3       PC4       PC5
# 66   1.747149 -1.512177  1.771193 -1.109244
# 132 -0.234852 -1.400625  2.563263  1.038041
# 32   1.283684 -0.093900  1.219203 -1.193889
# 31   0.383685 -0.317099  0.924645 -1.871714
# 97   0.554317 -0.232638  1.085072 -1.255420
# 112  0.959644 -0.562642  1.137342 -1.189647
# 3    1.698771  1.525076  0.855595 -0.214778
# 25   0.034132 -0.448309  1.085256 -0.705788
# 37   1.050880 -0.016341  1.572625  0.693081
# 64  -0.095961 -1.206630  1.127756 -0.570452

# %%
#Under Developed Countries
kMean_DF[(kMean_DF['ClusterId'] == 0)].sort_values(by=['life_expec']).head(5)
# Out:
#      ClusterId                   country  child_mort  exports  health  \
# 66   0          Haiti                     208.0       15.3     6.91
# 87   0          Lesotho                   99.7        39.4     11.10
# 31   0          Central African Republic  149.0       11.8     3.98
# 166  0          Zambia                    83.1        37.0     5.89
# 94   0          Malawi                    90.5        22.8     6.59
#
#      imports  income  inflation  life_expec  total_fer  gdpp       PC1  \
# 66   64.7     1500    5.45       32.1        3.33       662  -4.408941
# 87   101.0    2380    4.15       46.5        3.30       1170 -1.802459
# 31   26.5     888     2.01       47.5        5.21       446  -3.965158
# 166  30.9     3280    14.00      52.0        5.40       1460 -2.863885
# 94   34.9     1030    12.10      53.1        5.31       459  -2.979725
#
#           PC2       PC3       PC4       PC5
# 66   1.747149 -1.512177  1.771193 -1.109244
# 87   2.037592 -2.545362  1.037138  0.725376
# 31   0.383685 -0.317099  0.924645 -1.871714
# 166  0.487336  0.221918  0.818991 -0.265921
# 94   0.216437 -0.208393  0.838092 -0.232221

# %%
#Under Developed Countries
kMean_DF[(kMean_DF['ClusterId'] == 0)].sort_values(by=['inflation'], ascending=False).head(5)
# Out:
#      ClusterId            country  child_mort  exports  health  imports  \
# 149  0          Timor-Leste        62.6        2.2      9.12    27.8
# 49   0          Equatorial Guinea  111.0       85.8     4.48    58.9
# 165  0          Yemen              56.3        30.0     5.18    34.4
# 3    0          Angola             119.0       62.3     2.85    42.9
# 37   0          Congo, Dem. Rep.   116.0       41.1     7.91    49.6
#
#      income  inflation  life_expec  total_fer   gdpp       PC1       PC2  \
# 149  1850    26.5       71.1        6.23       3600  -2.371889 -1.176966
# 49   33700   24.9       60.9        5.21       17100 -1.293264  2.372017
# 165  4480    23.6       67.5        4.67       1310  -1.887294 -0.105397
# 3    5900    22.4       60.1        6.16       3530  -2.932714  1.698771
# 37   609     20.8       57.5        6.54       334   -3.173421  1.050880
#
#           PC3       PC4       PC5
# 149  0.392827  1.159493  1.418366
# 49   1.758962  1.748293  0.091883
# 165  1.107639  0.062636  0.665467
# 3    1.525076  0.855595 -0.214778
# 37  -0.016341  1.572625  0.693081

# %%
kMean_DF[(kMean_DF['ClusterId'] == 4)]
# Out:
#      ClusterId    country  child_mort  exports  health  imports  income  \
# 103  4          Mongolia   26.1        46.7     5.44    56.7     7710
# 113  4          Nigeria    130.0       25.3     5.07    17.4     5150
# 163  4          Venezuela  17.1        28.5     4.91    17.6     16500
#
#      inflation  life_expec  total_fer   gdpp       PC1       PC2       PC3  \
# 103  39.2       66.2        2.64       2650  -0.943813  0.545568  1.816423
# 113  104.0      60.5        5.84       2330  -4.909489 -0.051773  6.010058
# 163  45.9       75.4        2.47       13500 -0.549894 -1.215018  3.074556
#
#           PC4       PC5
# 103 -0.401107  2.221377
# 113  2.414875  5.404537
# 163 -0.108594  2.114025

# %% [markdown]
# Based on above analysis and key features like **Chile Mortality, GDPP, Inflation, Life Expectancy** we can Cheery Pick countries which are in direst need of aid<BR>
# <ul>
#     <li>**Haiti** : Very high Child Mortality rate **208**& very low life expectancy **32**</li>
#     <li>**Sierra Leone** : Same as Haiti, this country also have very high Child Mortality rate & low life expectancy, GDPP of this country is very low **399** and Inflation is very high **17.20** (more than 75% from that Cluster) </li>
#     <li>**Chad & Central African Republic** : Both the countries showing same trend High Child Mortality with Low Life Expectancy as well as Low GDPP. **Chad** have very high Total fertility ration </li>
#     <li>**Nigeria** : This country from cluster 4 have very high Inflation rate **104** and high child mortality **130**. </li>
#     <li>**Mali** : Here Total Fertility to each women is very high **6.55** which can impact high Child Mortality **137**. </li>
#     <li>**Niger** : With very high Total fertility rate and low GDPP this country also facing High Child Mortality problem.</li>
# </ul>

# %% [markdown]
# ### Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
plt.figure(figsize=(18,6))
mergings = linkage(trainDf_pca, method = "complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
#Will use same cluster size as K-Mean Algo
clusterCut = pd.Series(cut_tree(mergings, n_clusters = 5).reshape(-1,), name="ClusterId")
hierar_DF = pd.concat([clusterCut, countryDf, trainDf_pca], axis=1)
hierar_DF.head()
# Out:
#    ClusterId              country  child_mort  exports  health  imports  \
# 0  0          Afghanistan          90.2        10.0     7.58    44.9
# 1  1          Albania              16.6        28.0     6.55    48.6
# 2  1          Algeria              27.3        38.4     4.17    31.4
# 3  0          Angola               119.0       62.3     2.85    42.9
# 4  1          Antigua and Barbuda  10.3        45.5     6.03    58.9
#
#    income  inflation  life_expec  total_fer   gdpp       PC1       PC2  \
# 0  1610    9.44       56.2        5.82       553   -2.913000  0.091969
# 1  9930    4.49       76.3        1.65       4090   0.429870 -0.589373
# 2  12900   16.10      76.5        2.89       4460  -0.285289 -0.452139
# 3  5900    22.40      60.1        6.16       3530  -2.932714  1.698771
# 4  19100   1.44       76.8        2.13       12200  1.033371  0.133853
#
#         PC3       PC4       PC5
# 0 -0.721242  1.001838 -0.146765
# 1 -0.328611 -1.165014  0.153205
# 2  1.232051 -0.857767  0.191227
# 3  1.525076  0.855595 -0.214778
# 4 -0.216699 -0.846638 -0.193186

# %%
hierar_DF['ClusterId'].value_counts()
# Out:
# 1    94
# 0    38
# 2    30
# 3    4
# 4    1
# Name: ClusterId, dtype: int64

# %%
grpHierarClust = hierar_DF.groupby(by=['ClusterId']).mean()
grpHierarClust = grpHierarClust.reset_index()
grpHierarClust
# Out:
#    ClusterId  child_mort     exports    health     imports        income  \
# 0  0          96.000000   30.537368   7.028684  47.913158   3508.763158
# 1  1          25.538298   38.631691   6.183511  45.263467   11871.063830
# 2  2          6.190000    47.543333   8.701000  38.660000   46543.333333
# 3  3          6.700000    155.450000  5.945000  144.500000  53125.000000
# 4  4          130.000000  25.300000   5.070000  17.400000   5150.000000
#
#     inflation  life_expec  total_fer          gdpp       PC1       PC2  \
# 0  8.198553    57.884211   5.061579   1793.342105  -2.397985  0.594264
# 1  7.979511    72.460638   2.455106   6878.053191   0.041007 -0.195184
# 2  4.358433    79.790000   1.901333   42150.000000  2.473202 -0.780725
# 3  0.798500    79.425000   1.577500   45875.000000  4.495544  4.809682
# 4  104.000000  60.500000   5.840000   2330.000000  -4.909489 -0.051773
#
#         PC3       PC4       PC5
# 0 -0.560339  0.785028 -0.245695
# 1  0.064347 -0.669008  0.116076
# 2  0.302701  0.977933 -0.260208
# 3  0.038292  0.325708  0.206745
# 4  6.010058  2.414875  5.404537

# %% [markdown]
# Looks like **Cluster Id - 4 ** is group of under developed countries with High Chile Mortality, Very High Inflation Rate, Low GDPP, Low Heath Expenditure. But there is only 1 country assigned in that group. <BR>
# **Cluster Id - 0** is another group shows similar trend and 38 countries assigned to that group.

# %%
plt.figure(figsize=(12,5))
sns.scatterplot(data=hierar_DF, x='PC1', y='PC2', hue='ClusterId', style='ClusterId', legend="full")

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.scatterplot(data=hierar_DF, x='gdpp', y='exports', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,2)
sns.scatterplot(data=hierar_DF, x='gdpp', y='life_expec', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,3)
sns.scatterplot(data=hierar_DF, x='gdpp', y='child_mort', hue='ClusterId', style='ClusterId', legend="full")
plt.subplot(2,2,4)
sns.scatterplot(data=hierar_DF, x='gdpp', y='income', hue='ClusterId', style='ClusterId', legend="full")

# %% [markdown]
# More precise segregation of data in Hierarchical Clustering than KMean.

# %%
plt.figure(figsize=(17,10))
plt.subplot(3,3,1)
sns.barplot(data=grpHierarClust, x='ClusterId', y='child_mort')
plt.subplot(3,3,2)
sns.barplot(data=grpHierarClust, x='ClusterId', y='exports')
plt.subplot(3,3,3)
sns.barplot(data=grpHierarClust, x='ClusterId', y='health')

plt.subplot(3,3,4)
sns.barplot(data=grpHierarClust, x='ClusterId', y='imports')
plt.subplot(3,3,5)
sns.barplot(data=grpHierarClust, x='ClusterId', y='income')
plt.subplot(3,3,6)
sns.barplot(data=grpHierarClust, x='ClusterId', y='inflation')
plt.subplot(3,3,7)

sns.barplot(data=grpHierarClust, x='ClusterId', y='life_expec')
plt.subplot(3,3,8)
sns.barplot(data=grpHierarClust, x='ClusterId', y='total_fer')
plt.subplot(3,3,9)
sns.barplot(data=grpHierarClust, x='ClusterId', y='gdpp')
plt.show()

# %%
hierar_DF[(hierar_DF['ClusterId'] == 0)].describe()
# Out:
#        ClusterId  child_mort    exports     health     imports        income  \
# count  38.0       38.000000   38.000000  38.000000  38.000000   38.000000
# mean   0.0        96.000000   30.537368  7.028684   47.913158   3508.763158
# std    0.0        35.676974   18.664812  2.892892   18.882999   5774.752885
# min    0.0        28.100000   8.920000   2.460000   26.500000   609.000000
# 25%    0.0        68.075000   17.500000  4.942500   34.600000   1252.500000
# 50%    0.0        92.050000   23.650000  6.300000   43.250000   1755.000000
# 75%    0.0        113.250000  40.000000  8.537500   56.650000   2682.500000
# max    0.0        208.000000  85.800000  14.200000  101.000000  33700.000000
#
#        inflation  life_expec  total_fer          gdpp        PC1        PC2  \
# count  38.000000  38.000000   38.000000  38.000000     38.000000  38.000000
# mean   8.198553   57.884211   5.061579   1793.342105  -2.397985   0.594264
# std    6.700538   6.308104    1.087053   3029.981663   0.932876   0.794097
# min    0.885000   32.100000   2.590000   231.000000   -4.408941  -1.007969
# 25%    3.117500   56.225000   4.570000   548.500000   -2.960352   0.076449
# 50%    5.910000   58.300000   5.205000   733.000000   -2.627568   0.435727
# 75%    11.725000  60.875000   5.672500   1305.000000  -1.780758   1.049881
# max    24.900000  68.200000   7.490000   17100.000000 -0.380657   2.372017
#
#              PC3        PC4        PC5
# count  38.000000  38.000000  38.000000
# mean  -0.560339   0.785028  -0.245695
# std    1.023006   0.610087   0.792977
# min   -2.742965  -0.279117  -1.871714
# 25%   -1.214588   0.412311  -0.789771
# 50%   -0.411810   0.705436  -0.244111
# 75%   -0.212984   1.117131   0.218076
# max    1.758962   2.563263   1.576650

# %%
hierar_DF[(hierar_DF['ClusterId'] == 4)]
# Out:
#      ClusterId  country  child_mort  exports  health  imports  income  \
# 113  4          Nigeria  130.0       25.3     5.07    17.4     5150
#
#      inflation  life_expec  total_fer  gdpp       PC1       PC2       PC3  \
# 113  104.0      60.5        5.84       2330 -4.909489 -0.051773  6.010058
#
#           PC4       PC5
# 113  2.414875  5.404537

# %%
hierar_DF[(hierar_DF['ClusterId'] == 0)].sort_values(by=['child_mort'], ascending=False).head(10)
# Out:
#      ClusterId                   country  child_mort  exports  health  \
# 66   0          Haiti                     208.0       15.3     6.91
# 132  0          Sierra Leone              160.0       16.8     13.10
# 32   0          Chad                      150.0       36.8     4.53
# 31   0          Central African Republic  149.0       11.8     3.98
# 97   0          Mali                      137.0       22.8     4.98
# 112  0          Niger                     123.0       22.2     5.16
# 3    0          Angola                    119.0       62.3     2.85
# 25   0          Burkina Faso              116.0       19.2     6.74
# 37   0          Congo, Dem. Rep.          116.0       41.1     7.91
# 64   0          Guinea-Bissau             114.0       14.9     8.50
#
#      imports  income  inflation  life_expec  total_fer  gdpp       PC1  \
# 66   64.7     1500    5.45       32.1        3.33       662  -4.408941
# 132  34.5     1220    17.20      55.0        5.20       399  -3.381422
# 32   43.5     1930    6.39       56.5        6.59       897  -3.558249
# 31   26.5     888     2.01       47.5        5.21       446  -3.965158
# 97   35.1     1870    4.37       59.5        6.55       708  -3.413005
# 112  49.1     814     2.55       58.8        7.49       348  -3.450990
# 3    42.9     5900    22.40      60.1        6.16       3530 -2.932714
# 25   29.6     1430    6.81       57.9        5.87       575  -3.122430
# 37   49.6     609     20.80      57.5        6.54       334  -3.173421
# 64   35.2     1390    2.97       55.6        5.05       547  -2.833802
#
#           PC2       PC3       PC4       PC5
# 66   1.747149 -1.512177  1.771193 -1.109244
# 132 -0.234852 -1.400625  2.563263  1.038041
# 32   1.283684 -0.093900  1.219203 -1.193889
# 31   0.383685 -0.317099  0.924645 -1.871714
# 97   0.554317 -0.232638  1.085072 -1.255420
# 112  0.959644 -0.562642  1.137342 -1.189647
# 3    1.698771  1.525076  0.855595 -0.214778
# 25   0.034132 -0.448309  1.085256 -0.705788
# 37   1.050880 -0.016341  1.572625  0.693081
# 64  -0.095961 -1.206630  1.127756 -0.570452

# %%
hierar_DF[(hierar_DF['ClusterId'] == 0)].sort_values(by=['life_expec']).head(5)
# Out:
#      ClusterId                   country  child_mort  exports  health  \
# 66   0          Haiti                     208.0       15.3     6.91
# 87   0          Lesotho                   99.7        39.4     11.10
# 31   0          Central African Republic  149.0       11.8     3.98
# 166  0          Zambia                    83.1        37.0     5.89
# 94   0          Malawi                    90.5        22.8     6.59
#
#      imports  income  inflation  life_expec  total_fer  gdpp       PC1  \
# 66   64.7     1500    5.45       32.1        3.33       662  -4.408941
# 87   101.0    2380    4.15       46.5        3.30       1170 -1.802459
# 31   26.5     888     2.01       47.5        5.21       446  -3.965158
# 166  30.9     3280    14.00      52.0        5.40       1460 -2.863885
# 94   34.9     1030    12.10      53.1        5.31       459  -2.979725
#
#           PC2       PC3       PC4       PC5
# 66   1.747149 -1.512177  1.771193 -1.109244
# 87   2.037592 -2.545362  1.037138  0.725376
# 31   0.383685 -0.317099  0.924645 -1.871714
# 166  0.487336  0.221918  0.818991 -0.265921
# 94   0.216437 -0.208393  0.838092 -0.232221

# %%
hierar_DF[(hierar_DF['ClusterId'] == 0)].sort_values(by=['gdpp']).head(5)
# Out:
#      ClusterId           country  child_mort  exports  health  imports  \
# 26   0          Burundi           93.6        8.92     11.60   39.2
# 88   0          Liberia           89.3        19.10    11.80   92.6
# 37   0          Congo, Dem. Rep.  116.0       41.10    7.91    49.6
# 112  0          Niger             123.0       22.20    5.16    49.1
# 132  0          Sierra Leone      160.0       16.80    13.10   34.5
#
#      income  inflation  life_expec  total_fer  gdpp       PC1       PC2  \
# 26   764     12.30      57.7        6.26       231  -2.898911 -0.426694
# 88   700     5.47       60.8        5.02       327  -1.773525  1.046886
# 37   609     20.80      57.5        6.54       334  -3.173421  1.050880
# 112  814     2.55       58.8        7.49       348  -3.450990  0.959644
# 132  1220    17.20      55.0        5.20       399  -3.381422 -0.234852
#
#           PC3       PC4       PC5
# 26  -1.360086  1.809782  0.742353
# 88  -2.419179  1.154309  1.015929
# 37  -0.016341  1.572625  0.693081
# 112 -0.562642  1.137342 -1.189647
# 132 -1.400625  2.563263  1.038041

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In both the clustering algorithm similar kind of clusters generated.<BR>
# Both methods shows **Cluster 0 & Cluster 4** contains under developed countries and faces similar kind of problems.

# %% [markdown]
# We have finalized below mentioned list of countries which are in direst need of aid:
# <ol>
#     <li>**Haiti**</li>
#     <li>**Sierra Leone**</li>
#     <li>**Chad**</li>
#     <li>**Central African Republic**</li>
#     <li>**Nigeria**</li>
#     <li>**Mali**</li>
#     <li>**Niger**</li>
# </ol>

# %%
kMean_DF.to_csv('kMean_Clustering.csv')
